# %%
import pandas as pd
import numpy as np

# %%
# !ls
# Out:
# AirQualityUCI  AirQualityUCI.csv  preprocessing.ipynb

# %%
data_raw = pd.read_csv("AirQualityUCI.csv",sep=";")
columns = ['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
           'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
           'PT08.S5(O3)', 'T', 'RH', 'AH']
data_raw = data_raw[columns]
data_raw = data_raw.iloc[:9357,:]
data_raw
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00     2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00       2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00     2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00     2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00     1,6       1272.0      51.0      6,5
# 5     10/03/2004  23.00.00     1,2       1197.0      38.0      4,7
# 6     11/03/2004  00.00.00     1,2       1185.0      31.0      3,6
# 7     11/03/2004  01.00.00       1       1136.0      31.0      3,3
# 8     11/03/2004  02.00.00     0,9       1094.0      24.0      2,3
# 9     11/03/2004  03.00.00     0,6       1010.0      19.0      1,7
# 10    11/03/2004  04.00.00    -200       1011.0      14.0      1,3
# 11    11/03/2004  05.00.00     0,7       1066.0       8.0      1,1
# 12    11/03/2004  06.00.00     0,7       1052.0      16.0      1,6
# ...

# %%
data_selected = data_raw[["Date", "Time", "CO(GT)"]]
data_selected
# Out:
#             Date      Time  CO(GT)
# 0     10/03/2004  18.00.00     2,6
# 1     10/03/2004  19.00.00       2
# 2     10/03/2004  20.00.00     2,2
# 3     10/03/2004  21.00.00     2,2
# 4     10/03/2004  22.00.00     1,6
# 5     10/03/2004  23.00.00     1,2
# 6     11/03/2004  00.00.00     1,2
# 7     11/03/2004  01.00.00       1
# 8     11/03/2004  02.00.00     0,9
# 9     11/03/2004  03.00.00     0,6
# 10    11/03/2004  04.00.00    -200
# 11    11/03/2004  05.00.00     0,7
# 12    11/03/2004  06.00.00     0,7
# 13    11/03/2004  07.00.00     1,1
# 14    11/03/2004  08.00.00       2
# 15    11/03/2004  09.00.00     2,2
# 16    11/03/2004  10.00.00     1,7
# 17    11/03/2004  11.00.00     1,5
# 18    11/03/2004  12.00.00     1,6
# 19    11/03/2004  13.00.00     1,9
# 20    11/03/2004  14.00.00     2,9
# 21    11/03/2004  15.00.00     2,2
# 22    11/03/2004  16.00.00     2,2
# 23    11/03/2004  17.00.00     2,9
# 24    11/03/2004  18.00.00     4,8
# 25    11/03/2004  19.00.00     6,9
# ...

# %%
data_formated = data_selected.copy()
data_formated = data_formated.set_index(['Date','Time']).unstack('Time')
data_formated
# Out:
#              CO(GT)                                                        \
# Time       00.00.00 01.00.00 02.00.00 03.00.00 04.00.00 05.00.00 06.00.00
# Date
# 01/01/2005     -200      1,6      2,5      2,7      1,9      1,4      1,5
# 01/02/2005      1,3      1,1      1,0      0,9      0,8      0,9      1,1
# 01/03/2005      0,6      0,6      0,4      0,2      0,2      0,2      0,2
# 01/04/2004      1,6      1,2      1,1      0,9      0,7      0,9      1,7
# 01/04/2005      0,7      0,6      0,5      0,5   -200,0      0,5      0,6
# 01/05/2004      3,5      2,4      1,6      1,3     -200      0,6      0,7
# 01/06/2004      0,3     -200     -200     -200     -200      0,1      0,3
# 01/07/2004      2,3      1,5      0,9      0,6      0,6      0,8      0,9
# 01/08/2004        2      1,8      0,9      0,5      0,6      0,4      0,4
# 01/09/2004      1,9      1,3      0,7      0,5      0,5      0,6      1,3
# 01/10/2004      1,9      1,6      1,3      0,8      0,6      0,7      1,6
# ...

# %%
aa.to_csv("airquality_format.csv", index=False)

# %%
a = pd.read_csv("airquality_format.csv", index_col=False)
a.columns = a.iloc[0]
a = a.drop(a.index[0])
a.to_csv("airquality_v1.csv", index=False)

# %%
b = pd.read_csv("airquality_v1.csv",index_col=False)
b
# Out:
#     00.00.00 01.00.00 02.00.00 03.00.00 04.00.00 05.00.00 06.00.00 07.00.00  \
# 0       -200      1,6      2,5      2,7      1,9      1,4      1,5      1,4
# 1        1,3      1,1      1,0      0,9      0,8      0,9      1,1      1,6
# 2        0,6      0,6      0,4      0,2      0,2      0,2      0,2      0,5
# 3        1,6      1,2      1,1      0,9      0,7      0,9      1,7      4,2
# 4        0,7      0,6      0,5      0,5   -200,0      0,5      0,6      1,5
# 5        3,5      2,4      1,6      1,3     -200      0,6      0,7      1,2
# 6        0,3     -200     -200     -200     -200      0,1      0,3      1,4
# 7        2,3      1,5      0,9      0,6      0,6      0,8      0,9      2,4
# 8          2      1,8      0,9      0,5      0,6      0,4      0,4      0,4
# 9        1,9      1,3      0,7      0,5      0,5      0,6      1,3      3,6
# 10       1,9      1,6      1,3      0,8      0,6      0,7      1,6      2,9
# ...
